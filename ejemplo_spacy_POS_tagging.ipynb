# %%
import spacy
import pandas as pd

# %%
nlp = spacy.load("es_core_news_sm")

# %%
doc = nlp(u"Muchos años después, frente al pelotón de fusilamiento, el coronel Aureliano Buendía había de recordar aquella tarde remota en que su padre lo llevó a conocer el hielo.")

# %%
resultado = pd.DataFrame(columns=['token', 'lema', 'pos', 'tag'])
for token in doc:
    resultado = resultado.append({
        'token': token.text,
        'lema': token.lemma_,
        'pos': token.pos_,
        'tag': token.tag_,},
        ignore_index=True)
    
resultado
# Out:
#            token          lema    pos  \
# 0         Muchos        Muchos    DET
# 1           años           año   NOUN
# 2        después       después    ADV
# 3              ,             ,  PUNCT
# 4         frente        frente   INTJ
# 5             al            al    ADP
# 6        pelotón       pelotón   NOUN
# 7             de            de    ADP
# 8   fusilamiento  fusilamiento   NOUN
# 9              ,             ,  PUNCT
# 10            el            el    DET
# 11       coronel       coronel   NOUN
# 12     Aureliano     Aureliano  PROPN
# 13       Buendía       Buendía  PROPN
# 14         había         haber   VERB
# 15            de            de    ADP
# 16      recordar      recordar   VERB
# 17       aquella         aquel    DET
# 18         tarde        tardar   NOUN
# 19        remota        remoto    ADJ
# 20            en            en    ADP
# 21           que           que  SCONJ
# 22            su            su    DET
# 23         padre         padre   NOUN
# 24            lo            el   PRON
# 25         llevó        llevar   VERB
# 26             a             a    ADP
# 27       conocer       conocer   VERB
# 28            el            el    DET
# 29         hielo         helar   NOUN
# 30             .             .  PUNCT
#
#                                                   tag
# 0   DET__Gender=Masc|Number=Plur|NumType=Card|Pron...
# 1                       NOUN__Gender=Masc|Number=Plur
# 2                                                 ADV
# 3                               PUNCT__PunctType=Comm
# 4                                                NOUN
# 5                               ADP__AdpType=Preppron
# 6                       NOUN__Gender=Masc|Number=Sing
# 7                                   ADP__AdpType=Prep
# 8                       NOUN__Gender=Masc|Number=Sing
# 9                               PUNCT__PunctType=Comm
# 10  DET__Definite=Def|Gender=Masc|Number=Sing|Pron...
# 11                      NOUN__Gender=Masc|Number=Sing
# 12                                              PROPN
# 13                                              PROPN
# 14  AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|V...
# 15                                  ADP__AdpType=Prep
# 16                                 VERB__VerbForm=Inf
# 17           DET__Gender=Fem|Number=Sing|PronType=Dem
# 18                       NOUN__Gender=Fem|Number=Sing
# 19                        ADJ__Gender=Fem|Number=Sing
# 20                                  ADP__AdpType=Prep
# 21                                              SCONJ
# 22    DET__Number=Sing|Person=3|Poss=Yes|PronType=Prs
# 23                      NOUN__Gender=Masc|Number=Sing
# 24  PRON__Case=Acc|Gender=Masc|Number=Sing|Person=...
# 25  VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past...
# 26                                  ADP__AdpType=Prep
# 27                                 VERB__VerbForm=Inf
# 28  DET__Definite=Def|Gender=Masc|Number=Sing|Pron...
# 29                      NOUN__Gender=Masc|Number=Sing
# 30                              PUNCT__PunctType=Peri
